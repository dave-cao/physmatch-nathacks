# %%
import pandas as pd


data=pd.read_csv("emotions.csv")

# %%
label_mapping = {
    'NEUTRAL': 0,
    'POSITIVE': 1,
    'NEGATIVE': -1
}

# Assuming 'label' column exists in the DataFrame 'data'
# Creating a new column 'Encoded_Label' based on label mapping
data['Encoded_Label'] = data['label'].map(label_mapping)
data
# Out:
#       # mean_0_a  mean_1_a  mean_2_a  mean_3_a  mean_4_a  mean_d_0_a  \
# 0          4.620      30.3    -356.0     15.60      26.3       1.070
# 1         28.800      33.1      32.0     25.80      22.8       6.550
# 2          8.900      29.4    -416.0     16.70      23.7      79.900
# 3         14.900      31.6    -143.0     19.80      24.3      -0.584
# 4         28.300      31.3      45.2     27.30      24.5      34.800
# ...          ...       ...       ...       ...       ...         ...
# 2127      32.400      32.2      32.2     30.80      23.4       1.640
# 2128      16.300      31.3    -284.0     14.30      23.9       4.200
# 2129      -0.547      28.3    -259.0     15.80      26.7       9.080
# 2130      16.800      19.9    -288.0      8.34      26.0       2.460
# 2131      27.000      32.0      31.8     25.00      28.9       4.990
#
#       mean_d_1_a  mean_d_2_a  mean_d_3_a  mean_d_4_a  ...  fft_742_b  \
# ...

# %%
# import matplotlib.pyplot as plt
# fft_data = data.loc[:,'fft_0_b':'fft_749_b']

# fft_data.iloc[0,:].plot(figsize=(15,10))
# data.drop(columns=['label'], inplace=True)

# %%
from sklearn.ensemble import RandomForestClassifier
from joblib import dump, load
train=data.iloc[0:1066]
test=data.iloc[1066:]
column_names_mean = data.columns[:4].tolist()
column_names_std = data.columns[60:64].tolist()
column_names_skew = [data.columns[70:78][i] for i in range(len(data.columns[70:78])) if int(i) % 2 == 0]
column_names_kurt = [data.columns[70:78][i] for i in range(len(data.columns[70:78])) if int(i) % 2 == 1]
column_names_max = data.columns[90:94].tolist()
column_names_min = data.columns[150:154].tolist()
column_names = column_names_mean + column_names_std + column_names_skew + column_names_kurt + column_names_max + column_names_min
column_names
# rf=RandomForestClassifier(min_samples_split=15,n_estimators=200,random_state=1)
# rf.fit(train[column_names], train["Encoded_Label"])
# pred= rf.predict(test[column_names])
# from sklearn.metrics import accuracy_score
# accuracy=accuracy_score(test["Encoded_Label"],pred)
# print(accuracy)
# # save model
# dump(rf, 'randomforest50.joblib')
# Out:
# ['# mean_0_a',
#  'mean_1_a',
#  'mean_2_a',
#  'mean_3_a',
#  'stddev_0_a',
#  'stddev_1_a',
#  'stddev_2_a',
#  'stddev_3_a',
#  'moments_0_a',
#  'moments_2_a',
#  'moments_4_a',
#  'moments_6_a',
#  'moments_1_a',
#  'moments_3_a',
#  'moments_5_a',
#  'moments_7_a',
#  'max_0_a',
#  'max_1_a',
#  'max_2_a',
#  'max_3_a',
#  'min_0_a',
#  'min_1_a',
#  'min_2_a',
#  'min_3_a']

# %%
combined=pd.DataFrame(dict(actual=test["Encoded_Label"], predictions=pred), index= test.index)
combined
# Out:
#       actual  predictions
# 1700       0            0
# 1701       1            1
# 1702       0            0
# 1703      -1           -1
# 1704       1            1
# ...      ...          ...
# 2127       0            0
# 2128       1            1
# 2129      -1           -1
# 2130      -1           -1
# 2131       0            0
#
# [432 rows x 2 columns]

# %%
import pickle
model_filename = "model.pkl"  
with open(model_filename, 'wb') as file:  
    pickle.dump(rf, file)

# %%
# Print the resampled data for inspection

# %%
import pandas as pd

# Read data from the CSV file into datanew DataFrame
datanew = pd.read_csv("mean_per_second_filtered.csv", index_col=0)
#print(datanew)
pred= rf.predict(datanew)
print(pred)
x={}
for i in pred:
    x[i]=1+x.get(i,0)
x
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\nnhun\OneDrive\Desktop\pm-model-rose\preet_files\randomforest.ipynb Cell 14 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/nnhun/OneDrive/Desktop/pm-model-rose/preet_files/randomforest.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
#       <a href='vscode-notebook-cell:/c%3A/Users/nnhun/OneDrive/Desktop/pm-model-rose/preet_files/randomforest.ipynb#X16sZmlsZQ%3D%3D?line=2'>3</a> # Read data from the CSV file into datanew DataFrame
# ----> <a href='vscode-notebook-cell:/c%3A/Users/nnhun/OneDrive/Desktop/pm-model-rose/preet_files/randomforest.ipynb#X16sZmlsZQ%3D%3D?line=3'>4</a> datanew = pd.read_csv("mean_per_second_filtered.csv", index_col=0)
# ...
